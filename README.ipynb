# %% [raw]
# The config file read during training is in: result/config.yaml, and the model code used for testing and evaluation is nn_module.py
# The training and evaluation results are stored in the result folder
# The historical model parameters, weights, and evaluations are in the log folder, with each result_i as a group
#
# The hand-drawing and prediction code is pad.py, and the model code used for prediction is pad_nn_module.py, and the weights are in pad/svhn_classifier.pth
# When you need to demonstrate hand-drawn predictions, just run pad.py directly. If you encounter a bug, you can refresh the webpagepage
# Project use anaconda environment: environment.yml

# %% [raw]
# Training Steps
# 1.Setting Hyperparameters: result/config.yaml
# 2.Training model: Run train.py, the program will automatically download the database and train the model, then save the weight dictionary

# %%
# %run train.py

# %% [raw]
# 3.Evaluate the model: Run the evaluate.py program to automatically load the weights result/svhn_classifier.pth and then test the model performance

# %%
# %run evaluate.py
# Out:
# C:\Users\19692\AppData\Roaming\Python\Python312\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [raw]
# 4.Check the results in the result folder

# %% [raw]
# Hand-drawn predictions(Automatically open with default browser.If you encounter a bug, you can refresh the webpage):

# %%
# !python pad.py
